# %%
import pandas as pd
import numpy as np

np.random.seed(42)
#Radom data set for PR to PO Operation 

#for 1000 Lines
n = 1000

data = {
    "PO_ID": range(10001, 10001 + n),
    "Supplier_ID": np.random.randint(200, 350, n),
    "Category": np.random.choice(["Direct", "Indirect"], n),
    "Region": np.random.choice(["NA", "EMEA", "APAC"], n),
    "Unit_Price": np.round(np.random.uniform(10, 500, n), 2),
    "Quantity": np.random.randint(1, 1000, n),
    "Lead_Time_Days": np.random.randint(5, 60, n),
    "On_Time_Delivery": np.random.choice([0, 1], n, p=[0.3, 0.7]),
    "Quality_Score": np.round(np.random.uniform(2.5, 5.0, n), 2)
}

df = pd.DataFrame(data)

df.head()

# %%
cluster_features = [
    "Unit_Price",
    "Quantity",
    "Lead_Time_Days",
    "On_Time_Delivery",
    "Quality_Score"
]
# Out:
#    PO_ID  Supplier_ID  Category Region  Unit_Price  Quantity  Lead_Time_Days  \
# 0  10001          302    Direct   APAC      330.55       591              36
# 1  10002          292    Direct   EMEA      107.07       215              40
# 2  10003          214    Direct   EMEA      287.01       526              41
# 3  10004          306  Indirect   APAC      237.33       215              30
# 4  10005          271  Indirect   EMEA      486.28       403              26
#
#    On_Time_Delivery  Quality_Score      Spend  Supplier_Risk
# 0                 1           3.79  195355.05              0
# 1                 0           2.76   23020.05              1
# 2                 1           4.38  150967.26              0
# 3                 1           4.77   51025.95              0
# 4                 0           4.36  195970.84              1
